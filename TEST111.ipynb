# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import numpy as np
from datetime import datetime
from datetime import datetime, timezone

# %%
import re
s1 = 'https://www.youtube.com/watch?v=r8B8jLzh-NQ&ab_channel=AleXa%E2%80%A2ZBLabel'
s2 = 'https://www.youtube.com/watch?v=Z9Y9Z9Y9Z9Y'
result = re.search(r'(?<=v=)[^&]+', s1)
result.group(0)
# Out:
# 'r8B8jLzh-NQ'

# %%
df = pd.read_csv('data_youtube1.csv', header = 0)
df.head()
# Out:
#             video_channelId video_channelTitle  video_channelSubscriber  \
# 0  UCx9hXYOCvUYwrprEqe4ZQHA     TREASURE (트레저)                  6520000
# 1  UCx9hXYOCvUYwrprEqe4ZQHA     TREASURE (트레저)                  6520000
# 2  UCx9hXYOCvUYwrprEqe4ZQHA     TREASURE (트레저)                  6520000
# 3  UCx9hXYOCvUYwrprEqe4ZQHA     TREASURE (트레저)                  6520000
# 4  UCx9hXYOCvUYwrprEqe4ZQHA     TREASURE (트레저)                  6520000
#
#       video_id                               video_title  \
# 0  60HQ7Ehrw3s             TREASURE - 'HELLO' M/V TEASER
# 1  G3IfWppzoGM       TREASURE - '직진 (JIKJIN)' M/V TEASER
# 2  nPAfTb_ipzU       TREASURE - ‘MY TREASURE’ M/V TEASER
# 3  OWcEcuR7wC0  TREASURE - '사랑해 (I LOVE YOU)' M/V TEASER
# 4  ATdZV3o2smY               TREASURE - 'BOY' M/V TEASER
#
#            video_publishedAt  \
# 0  2022-10-01 00:00:02+00:00
# 1  2022-02-11 15:00:07+00:00
# 2  2021-01-08 15:00:13+00:00
# 3  2020-09-15 15:00:07+00:00
# 4  2020-08-06 00:00:01+00:00
#
#                                    video_description  \
# 0  #TREASURE #트레저 #2ndMINIALBUM #THESECONDSTEP_CH...
# 1  #TREASURE #트레저 #1stMINIALBUM #THESECONDSTEP_CH...
# 2  #TREASURE #트레저 #1stALBUM #THEFIRSTSTEP_TREASUR...
# 3  #TREASURE #트레저 #2ndSINGLEALBUM #THEFIRSTSTEP_C...
# 4  #TREASURE #트레저 #1stSINGLEALBUM #THEFIRSTSTEP_C...
#
#                                  video_thumbnails  \
# 0  https://i.ytimg.com/vi/60HQ7Ehrw3s/default.jpg
# 1  https://i.ytimg.com/vi/G3IfWppzoGM/default.jpg
# 2  https://i.ytimg.com/vi/nPAfTb_ipzU/default.jpg
# 3  https://i.ytimg.com/vi/OWcEcuR7wC0/default.jpg
# 4  https://i.ytimg.com/vi/ATdZV3o2smY/default.jpg
#
#                                           video_tags  video_categoryId  \
# 0  ['YG Entertainment', 'YG', '와이지', 'K-pop', '트레...                24
# 1  ['YG Entertainment', 'YG', '와이지', 'K-pop', '트레...                24
# 2  ['YG Entertainment', 'YG', '와이지', 'K-pop', '트레...                24
# 3  ['YG Entertainment', 'YG', '와이지', 'K-pop', '트레...                24
# 4  ['YG Entertainment', 'YG', '와이지', 'K-pop', '트레...                24
#
#    video_viewCount  video_likeCount  video_commentCount video_duration_teaser  \
# 0        1646886.0         273079.0             20448.0                 PT30S
# 1        4227677.0         450287.0            108333.0                 PT27S
# 2        2138060.0         361087.0             39539.0                 PT36S
# 3        2751956.0         389661.0             28013.0                 PT28S
# 4        2745474.0         363527.0             24247.0                 PT30S
#
#   video_id_mv_official            video_title_mv_official  \
# 0          aPd9exmH17o             TREASURE - ‘HELLO’ M/V
# 1          ZJaKdBBzUYk       TREASURE - '직진 (JIKJIN)' M/V
# 2          p9LLoijPQfg       TREASURE - ‘MY TREASURE’ M/V
# 3          _hFarg-Obuc  TREASURE - ‘사랑해 (I LOVE YOU)’ M/V
# 4          JSAfPh1A25E               TREASURE - 'BOY' M/V
#
#   video_publishedAt_mv_official video_duration_mv_official  \
# 0     2022-10-04 09:17:22+00:00                     PT3M6S
# 1     2022-02-15 09:00:14+00:00                    PT3M10S
# 2     2021-01-11 09:00:11+00:00                    PT3M21S
# 3     2020-09-18 09:00:16+00:00                    PT3M10S
# 4     2020-08-07 09:00:09+00:00                    PT3M17S
#
#    video_viewCount_mv_official  total_hour_mv_published
# 0                   49741037.0                  48194.0
# 1                  106631939.0                 380851.0
# 2                   46239786.0                 956851.0
# 3                  102498239.0                1122451.0
# 4                  114760881.0                1182931.0

# %%
df['video_publishedAt']  = pd.to_datetime(df['video_publishedAt'])
df['video_publishedAt_mv_official']  = pd.to_datetime(df['video_publishedAt_mv_official'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   video_channelId                870 non-null    object
#  1   video_channelTitle             870 non-null    object
#  2   video_channelSubscriber        870 non-null    int64
#  3   video_id                       870 non-null    object
#  4   video_title                    870 non-null    object
#  5   video_publishedAt              870 non-null    datetime64[ns, UTC]
#  6   video_description              869 non-null    object
#  7   video_thumbnails               870 non-null    object
#  8   video_tags                     808 non-null    object
#  9   video_categoryId               870 non-null    int64
#  10  video_viewCount                870 non-null    float64
#  11  video_likeCount                867 non-null    float64
#  12  video_commentCount             870 non-null    float64
#  13  video_duration_teaser          870 non-null    object
#  14  video_id_mv_official           870 non-null    object
#  15  video_title_mv_official        870 non-null    object
#  16  video_publishedAt_mv_official  870 non-null    datetime64[ns, UTC]
#  17  video_duration_mv_official     870 non-null    object
#  18  video_viewCount_mv_official    870 non-null    float64
#  19  total_hour_mv_published        870 non-null    float64
# dtypes: datetime64[ns, UTC](2), float64(5), int64(2), object(11)
# memory usage: 136.1+ KB

# %% [markdown]
# Các hàm tạo thêm feature

# %%
# độ dài video (tính bằng giây)
def convert_duration_to_seconds(duration):
    x = re.findall("\d+", duration)
    seconds = 0
    if len(x)== 1:
        seconds = int(x[0])
    elif len(x)== 2:
        seconds = int(x[0])*60+int(x[1])
    return seconds

# %%
def get_seconds_video(df1, column):
    total_second = []
    column_list = list(df1[column])
    for value in column_list:
        if isinstance(value,str):
            total_second.append(convert_duration_to_seconds(value))
        else:
            total_second.append(np.nan)
    return total_second

# %%
# chuyển tags dạng string sang list
def convert_tags_to_list(string_tag):
    list_tag= re.sub('\\[|\\]','',string_tag).split(',')
    return list_tag

# %%
# tính len tags
def len_tags_teaser(df1):
    no_tags = []
    list_tags_teaser = list(df1['video_tags'])
    for list_tag in list_tags_teaser:
       
        if isinstance(list_tag,str):
            no_tags.append(len(convert_tags_to_list(list_tag)))
        else:
            no_tags.append(np.nan)
    return no_tags

# %%
# tính len của các gia trị có dạng string trong 1 cột
def len_feature_teaser(df1, column):
    len_features = []
    feature_teaser = list(df1[column])

    for value in feature_teaser :
        if isinstance(value,str):
            len_features.append(len(value))
        else:
            len_features.append(np.nan)
    return len_features

# %%
def total_hour_mv_teaser_publish(df1):
    list_total_seconds = []
    for i in range(df1.shape[0]):
        time_teaser = df1.iloc[i]['video_publishedAt'].to_pydatetime()
        time_mv = df1.iloc[i]['video_publishedAt_mv_official'].to_pydatetime()
        diff = time_mv -time_teaser
        list_total_seconds.append(diff.total_seconds()/60)
    return list_total_seconds

# %% [markdown]
# Tiền xử lý

# %%
df_v1 = df.copy()

# %%
df_v1['video_num_tag'] = len_tags_teaser(df_v1)
df_v1['video_title_len'] = len_feature_teaser(df_v1,'video_title')
df_v1['video_description_len'] = len_feature_teaser(df_v1,'video_description')
# df_v1['video_teaser_seconds'] = get_seconds_video(df_v1, 'video_duration_teaser')
# df_v1['video_mv_seconds'] = get_seconds_video(df_v1, 'video_duration_mv_official')
df_v1['total_hour_mv_teaser_publish'] = total_hour_mv_teaser_publish(df_v1)

# %%
num_pre = [
  'video_channelSubscriber',
  'video_viewCount',
  'video_likeCount',
  'video_commentCount',
  'video_num_tag',
  'video_title_len',
  'video_description_len',
  'total_hour_mv_teaser_publish',
  'total_hour_mv_published',
 'video_viewCount_mv_official',]

# %%
df_num = df_v1[num_pre]

# %%
df_num
# Out:
#      video_channelSubscriber  video_viewCount  video_likeCount  \
# 0                    6520000        1646886.0         273079.0
# 1                    6520000        4227677.0         450287.0
# 2                    6520000        2138060.0         361087.0
# 3                    6520000        2751956.0         389661.0
# 4                    6520000        2745474.0         363527.0
# ..                       ...              ...              ...
# 865                 82800000       33430640.0        2875684.0
# 866                 82800000       60837593.0        2596976.0
# 867                 82800000       11558606.0         969876.0
# 868                 82800000       30429205.0        1903457.0
# 869                 82800000       21553045.0        1252428.0
#
#      video_commentCount  video_num_tag  video_title_len  \
# 0               20448.0           38.0               29
# 1              108333.0           38.0               35
# 2               39539.0           46.0               35
# 3               28013.0           43.0               40
# 4               24247.0           42.0               27
# ..                  ...            ...              ...
# 865            155562.0           23.0               42
# 866            119070.0           18.0               39
# 867             28717.0           18.0               26
# 868            121823.0            4.0               45
# 869             38427.0           10.0               53
#
#      video_description_len  total_hour_mv_teaser_publish  \
# 0                    123.0                   4877.333333
# 1                     95.0                   5400.116667
# 2                     94.0                   3959.966667
# 3                     99.0                   3960.150000
# 4                     89.0                   1980.133333
# ..                     ...                           ...
# 865                   88.0                   3418.166667
# 866                  904.0                   2338.750000
# 867                   73.0                   4800.066667
# 868                  108.0                   1980.033333
# 869                  315.0                   3359.983333
#
#      total_hour_mv_published  video_viewCount_mv_official
# 0                    48194.0                 4.974104e+07
# 1                   380851.0                 1.066319e+08
# 2                   956851.0                 4.623979e+07
# 3                  1122451.0                 1.024982e+08
# 4                  1182931.0                 1.147609e+08
# ..                       ...                          ...
# 865                1243413.0                 1.162397e+09
# 866                1889612.0                 1.691670e+09
# 867                2095891.0                 8.713967e+08
# 868                2311891.0                 1.974993e+09
# 869                2827411.0                 1.224002e+09
#
# [870 rows x 10 columns]

# %%
# df_num= df_num[df_num['total_hour_mv_teaser_publish']>0] 
df_num= df_num[df_num['video_viewCount_mv_official']>1]

# %%
df_num.describe()
# Out:
#        video_channelSubscriber  video_viewCount  video_likeCount  \
# count             8.690000e+02     8.690000e+02     8.660000e+02
# mean              3.688394e+07     2.261083e+06     2.433228e+05
# std               1.908627e+07     5.937945e+06     5.629493e+05
# min               5.450000e+05     2.643200e+04     2.440000e+02
# 25%               3.100000e+07     2.749200e+05     2.547325e+04
# 50%               3.100000e+07     7.896740e+05     7.739800e+04
# 75%               3.100000e+07     1.981085e+06     2.445970e+05
# max               8.280000e+07     7.456323e+07     6.455006e+06
#
#        video_commentCount  video_num_tag  video_title_len  \
# count        8.690000e+02     807.000000       869.000000
# mean         1.567237e+04      19.363073        44.469505
# std          6.178645e+04      14.348750        13.593016
# min          2.300000e+01       2.000000        21.000000
# 25%          1.253000e+03       8.000000        34.000000
# 50%          3.698000e+03      15.000000        42.000000
# 75%          9.887000e+03      27.000000        52.000000
# max          1.120651e+06      75.000000       100.000000
#
#        video_description_len  total_hour_mv_teaser_publish  \
# count             868.000000                  8.690000e+02
# mean              634.587558                  1.080027e+04
# std               485.525901                  8.380388e+04
# min                33.000000                 -1.414509e+05
# 25%               350.750000                  1.799983e+03
# 50%               494.500000                  2.880067e+03
# 75%               695.250000                  5.399617e+03
# max              2955.000000                  1.640160e+06
#
#        total_hour_mv_published  video_viewCount_mv_official
# count             8.690000e+02                 8.690000e+02
# mean              1.847091e+06                 8.280798e+07
# std               1.482018e+06                 2.053519e+08
# min               1.395100e+04                 5.406300e+04
# 25%               7.048510e+05                 3.984191e+06
# 50%               1.548691e+06                 1.979996e+07
# 75%               2.669371e+06                 6.957284e+07
# max               6.930344e+06                 1.974993e+09

# %%
corr_= df_num.corr()
plt.figure(figsize=(15,12))
sns.heatmap(corr_, annot=True, fmt = ".2f", cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(25, 7))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=1, hspace=0.5)
for i in range(0, len(num_pre)):
    plt.subplot(1, 13, i+1)
    sns.boxplot(y=df_num[num_pre[i]],color='blue',orient='v')

# %%
q25,q75 = np.percentile(a = df_num['video_viewCount_mv_official'],q=[25,75])
IQR = q75 - q25
lower_limit = q25 - 1.5*IQR
upper_limit = q75 + 1.5*IQR
# for i in range(df_num.shape[0]):
#     if df_num['video_viewCount_mv_official'].iloc[i]<lower_limit or df_num['video_viewCount_mv_official'].iloc[i]>upper_limit:
#         df_num['video_viewCount_mv_official'].iloc[i] = np.nan

df_num = df_num[(df_num['video_viewCount_mv_official']> lower_limit) &(df_num['video_viewCount_mv_official']<upper_limit)]

# %%
# df_num = df_num[(df_num['total_hour_mv_teaser_publish'] < 0.5e6) ]
# df_num = df_num[df_num['video_mv_seconds'] <600]

df_num = df_num[df_num['video_viewCount'] <4e7]
df_num = df_num[df_num['video_likeCount'] <4e6]
df_num = df_num[df_num['video_commentCount'] <0.4e6]

# %%
# q25,q75 = np.percentile(a = df_num['video_viewCount'],q=[25,75])
# IQR = q75 - q25
# lower_limit = q25 - 1.5*IQR
# upper_limit = q75 + 1.5*IQR
# df_num = df_num[(df_num['video_viewCount']> lower_limit) &(df_num['video_viewCount']<upper_limit)]

# %%
df_num['video_num_tag'].fillna(df_num['video_num_tag'].mean(),  inplace=True)
df_num['video_description_len'].fillna(df_num['video_description_len'].mean(),  inplace=True)
df_num['video_likeCount'].fillna(df_num['video_likeCount'].mean(),  inplace=True)
# df_num['video_viewCount_mv_official'].fillna(df_num['video_viewCount_mv_official'].mean(),  inplace=True)

# %%
plt.figure(figsize=(25, 7))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=1, hspace=0.5)
for i in range(0, len(num_pre)):
    plt.subplot(1, 13, i+1)
    sns.boxplot(y=df_num[num_pre[i]],color='blue',orient='v')

# %%
df_num.shape
# Out:
# (782, 10)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df_train, df_test = train_test_split(df_num,test_size=0.2, random_state= 43, shuffle= True)
X_train = df_train.copy()
y_train = X_train.pop("video_viewCount_mv_official")

X_test = df_test.copy()
y_test = X_test.pop("video_viewCount_mv_official")

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
def eval_regression(model, pred, xtrain, ytrain, xtest, ytest):
    print("MAE: %.2f" % mean_absolute_error(ytest, pred)) 
    print("MSE: %.2f" % mean_squared_error(ytest, pred, squared=False)) 
    print('R2 score: %.2f' % r2_score(ytest, pred))

# %%
# # LINEAR REGRESSION

from sklearn.linear_model import LinearRegression


model = LinearRegression()
model.fit(X_train, y_train)

# predicting the  test set results
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)


eval_regression(model, y_pred_test, X_train, y_train, X_test, y_test)
# Out:
# MAE: 17056262.08
# MSE: 23887742.52
# R2 score: 0.62

# %%
from sklearn.linear_model import Ridge
reg_ridge = Ridge(alpha = 3)
reg_ridge.fit(X_train, y_train)
y_pred = reg_ridge.predict(X_test)
eval_regression(reg_ridge, y_pred, X_train, y_train, X_test, y_test)
# Out:
# MAE: 22051318.37
# MSE: 28862712.87
# R2 score: 0.45

# %%
from sklearn.linear_model import Lasso


reg_lasso = Lasso(alpha = 1)
reg_lasso.fit(X_train, y_train)

y_pred = reg_lasso.predict(X_test)
eval_regression(reg_lasso, y_pred, X_train, y_train, X_test, y_test)
# Out:
# MAE: 17056269.65
# MSE: 23887750.63
# R2 score: 0.62

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

params = {
    "n_estimators": [10, 20, 30, 50, 100, 150, 200],
    "max_features": ["auto", "sqrt", "log2", None],
    "max_depth": list(range(2, 11)) + [None]
}
gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=params, cv=5, scoring="neg_mean_squared_error")
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# {'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}

# %%
model = RandomForestRegressor(**gs.best_params_)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
eval_regression(model, y_pred, X_train, y_train, X_test, y_test)
# Out:
# MAE: 12185939.05
# MSE: 19412757.60
# R2 score: 0.75

# %%
import pickle
pickle.dump(model,open('rfrmodel.pkl','wb'))
pickle.dump(scaler,open('scale.pkl','wb'))

# %%
from sklearn.ensemble import RandomForestRegressor


# rf = RandomForestRegressor(random_state= 103)
# best_model1 = rf.fit(X_train, y_train)
# y_pred = rf.predict(X_test)
# eval_regression(rf, y_pred, X_train, y_train, X_test, y_test)
#

# %%
len(y_pred)
# Out:
# 157

# %%
d1 = {'True Labels': y_test, 'Predicted Labels': y_pred}
SK = pd.DataFrame(data = d1)
SK['diff'] = abs(SK['True Labels']- SK['Predicted Labels'])
SK[SK['diff']<10000000].reset_index()
# Out:
#     index  True Labels  Predicted Labels         diff
# 0     619    4169980.0      4.265533e+06    95552.575
# 1     553    1192637.0      7.912026e+06  6719389.120
# 2     132    3224504.0      1.272651e+07  9502007.435
# 3     753   25862873.0      3.107009e+07  5207218.105
# 4     150    1728915.0      2.660693e+06   931778.315
# ..    ...          ...               ...          ...
# 93    195     306899.0      4.338368e+05   126937.845
# 94    292    7183936.0      8.524899e+06  1340963.380
# 95    345   12057474.0      4.385469e+06  7672005.110
# 96    457   22421584.0      1.878069e+07  3640892.535
# 97    257    3678477.0      4.522884e+06   844406.800
#
# [98 rows x 4 columns]

# %%
SK.describe()
# Out:
#         True Labels  Predicted Labels          diff
# count  1.570000e+02      1.570000e+02  1.570000e+02
# mean   3.385670e+07      3.335324e+07  1.218594e+07
# std    3.887498e+07      3.319481e+07  1.515988e+07
# min    8.883500e+04      3.038948e+05  3.368400e+03
# 25%    3.224504e+06      6.222516e+06  1.758313e+06
# 50%    1.730207e+07      2.243603e+07  6.719389e+06
# 75%    5.692106e+07      5.430999e+07  1.705458e+07
# max    1.602030e+08      1.543118e+08  1.025364e+08

# %%
lm1 = sns.lmplot(x="True Labels", y="Predicted Labels", data = SK[["True Labels",'Predicted Labels']])
fig1 = lm1.fig 
fig1.suptitle("Sklearn", fontsize=18)
sns.set(font_scale = 1.5)

# %%
ls = ['video_channelSubscriber', 'video_viewCount', 'video_likeCount', 'video_commentCount' , 'no_tag', 'len_description',  'len_titile' , 'hour_teaser_with_mv', 'hour_publised_mv']
